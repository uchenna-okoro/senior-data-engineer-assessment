# %%
username = "Admin"
password = "Password123"

if username == "Admin" and password == "Password123":
    print("Authentication Successful")
else:
    print("Authentication Failed")
# Out:
# Authentication Successful

# %% [markdown]
# STEP 1 — Authentication (Pseudo Credentials)

# %%
username = "admin_user"
password = "fake_password"
tenant_id = "tenant_001"

print("Authenticating to BI Platform...")

if username == "admin_user" and password == "fake_password":
    access_granted = True
    print("Authentication Successful (Pseudo Mode)")
else:
    access_granted = False
    print("Authentication Failed")
# Out:
# Authenticating to BI Platform...
# Authentication Successful (Pseudo Mode)

# %% [markdown]
# STEP 2 — Define Dev and Test Environments

# %%
# STEP 2: Define environments

source_env = "/Dev"
target_env = "/Test"

artifact_id = "BI_REPORT_001"

print(f"Source: {source_env}")
print(f"Target: {target_env}")
print(f"Artifact: {artifact_id}")
# Out:
# Source: /Dev
# Target: /Test
# Artifact: BI_REPORT_001

# %% [markdown]
# STEP 3 — Simulate Deployment (REST API Call)

# %%
# STEP 3: Simulated REST API deployment

if access_granted:
    print("Calling BI REST API...")

    deployment_status = {
        "status": "SUCCESS",
        "operation_id": "op_12345"
    }

    print("Deployment from Dev → Test completed")
else:
    print("Deployment blocked due to authentication failure")
# Out:
# Calling BI REST API...
# Deployment from Dev → Test completed

# %% [markdown]
# STEP 4 — Validate Deployment

# %%
# STEP 4: Validate deployment

if deployment_status["status"] == "SUCCESS":
    print("Deployment Validation: SUCCESS")
else:
    print("Deployment Validation: FAILED")
# Out:
# Deployment Validation: SUCCESS

# %% [markdown]
# STEP 5 — Refresh Dataset (Test Environment)

# %%
# STEP 5: Refresh target environment

if deployment_status["status"] == "SUCCESS":
    print("Refreshing Test environment dataset...")
    print("Refresh completed successfully")
# Out:
# Refreshing Test environment dataset...
# Refresh completed successfully
